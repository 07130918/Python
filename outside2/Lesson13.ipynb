# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.random.rand(5)
y *= 5
y
# Out:
# array([1.51604248, 4.1390235 , 0.14246601, 4.62461162, 3.95714942])

# %%
plt.plot(y)

# %%
x = np.arange(1, 11, 2)
y = np.random.rand(5)
y *= 5
plt.plot(x, y, linestyle="-.")

# %%
x = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
y = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.title("Year - Count")
plt.xlabel("Year")
plt.ylabel("Count")
plt.grid(True)

plt.plot(x, y)

# %%
year = np.array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
count = np.array([400, 300, 350, 450, 400, 600, 500, 450])

plt.bar(year, count)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.barh(year, count)
# Out:
# <BarContainer object of 8 artists>

# %%
english = np.array([70, 95, 83, 100, 72, 71, 75, 85, 67, 75])
math = np.array([90, 82, 100, 95, 50, 81, 52, 56, 67, 71])
plt.scatter(english, math)

# %%
fruits = np.array(["peach", "orange", "grape", "banana", "apple"])
count = np.array([12, 20, 34, 36, 47])

plt.pie(count, labels = fruits, autopct = "%.1f%%", startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f035e5c3d30>,
#   <matplotlib.patches.Wedge at 0x7f035e54d220>,
#   <matplotlib.patches.Wedge at 0x7f035e54d8b0>,
#   <matplotlib.patches.Wedge at 0x7f035e54df40>,
#   <matplotlib.patches.Wedge at 0x7f035e557610>],
#  [Text(-0.2753556199584606, 1.0649785361955855, 'peach'),
#   Text(-0.8802793566494439, 0.6596273601487748, 'orange'),
#   Text(-0.9677114902133418, -0.5230052310532596, 'grape'),
#   Text(0.42897379439677824, -1.0129074408458212, 'banana'),
#   Text(0.9202149419690582, 0.6026644676574877, 'apple')],
#  [Text(-0.15019397452279665, 0.5808973833794102, '8.1%'),
#   Text(-0.480152376354242, 0.3597967418993317, '13.4%'),
#   Text(-0.5278426310254591, -0.2852755805745052, '22.8%'),
#   Text(0.23398570603460628, -0.5524949677340842, '24.2%'),
#   Text(0.5019354228922135, 0.3287260732677206, '31.5%')])

# %%
y1 = np.random.rand(11)
y2 = np.random.rand(11)

plt.plot(y1, color="blue", label = "y1")
plt.plot(y2, color="red", label = "y2")
plt.legend(loc="upper left")

# %%
y1 = np.random.rand(11)
y2 = np.random.rand(11)

fig = plt.figure()

# fig.add_subplot(行, 列, 何番目の領域に描画するか)
sp1 = fig.add_subplot(2, 1, 1)
sp1.plot(y1)

sp2 = fig.add_subplot(2, 1, 2)
sp2.plot(y2)

# %%
x = np.array([20, 30, 40, 50, 60])
y = np.array([30, 38, 41, 49, 62])

# y = ax + b(第3引数は１次式であることを示すため1)
p = np.polyfit(x, y, 1)
f = np.poly1d(p)

plt.scatter(x, y)
plt.plot(x, f(x))
