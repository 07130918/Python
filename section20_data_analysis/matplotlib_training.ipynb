# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel( ' some numbers ' )
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 8, 27, 64])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 8, 27, 64], 'bo')
plt.axis([0, 5, 0, 65])
plt.show()

# %%
t = np.arange(0, 10, 0.4)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x7f86f83d89a0>,
#  <matplotlib.lines.Line2D at 0x7f86f83d8850>,
#  <matplotlib.lines.Line2D at 0x7f86f83d89d0>]

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
area = np.random.rand(50) * 1000
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
objects = ('a', 'b', 'c', 'd', 'e', 'f')
y_pos = np.arange(len(objects))
value = [2, 2, 3, 4, 5, 6]
plt.bar(y_pos, value)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Title')
plt.show()

# %%
labels = ('Python', 'C++', 'Ruby', 'Java')
sizes = [10, 20 , 30, 40]
colors = ['blue', 'green', 'red', 'brown']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()

# %%
y = [2, 4, 6, 8, 10]
y2 = [10, 11, 12, 13, 14]
x = np.arange(5)

plt.plot(x, y, label='Y')
plt.plot(x, y2, label='Y2')
plt.legend()
plt.show()
